# %%
#Define a Piggy Bank Class

class piggyBank:
    
    #define constructor for the same
    def __init__(self):
        pass
    #pass is execute nothing
    
    #define a method to add amount into the piggybank
    def addMoney(self, amount):
        global saving
        saving = saving + int(amount)
        return "\nAmount " + amount + " added. Current Balance is: " +str(saving)
    
    #define a method to withdrawamount into the piggybank
    def withdrawMoney(self, amount):
        global saving
        if int(amount) > saving:
            return "Insufficient Funds"
        else:
            saving = saving - int(amount)
            return "\nAmount " + amount + "withdrawn. Current Balance is: " +str(saving)
        
        #define a method to check amount into the piggybank
    def checkMoney(self):
        global saving
        return  "\nCurrent Balance is : " + str(saving)
        
#Driver code/Main code

saving = 0
while True:
#The while loop will run as long as the conditional expression evaluates to True
    #Check whether the user wants to Start or End
    #Strip removes the trailing and leading specified character
    user_input = input("'Start' or 'End': ").strip(" ").lower()
    
    if user_input == "start":
        #create an object of the class
        pg_bank = piggyBank()
        
        while True:
            user_input1 = input("Add , Withdraw or Check : ").strip(" ").lower()
            if user_input1 == "add":
                amount = input("Please Enter the amount : ").strip(" ")
                print (pg_bank.addMoney(amount), "\n")
                break
            elif user_input1 == "withdraw": 
                amount = input("Please Enter the amount : ").strip(" ")
                print (pg_bank.withdrawMoney(amount), "\n")
                break
            elif user_input1 == "check":
                print (pg_bank.checkMoney() , "\n")
                break
            else:
                continue
                
    elif user_input == "end":
        print("Thank You!")
        break
    else:
        continue
